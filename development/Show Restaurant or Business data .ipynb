# %%
import pandas as pd
import sys
sys.path.append('/Users/linda/SFpal/data') #Linda: Mac

# %%
restaurants = pd.read_csv('/Users/linda/SFpal/data/raw_data/Restaurant_Scores.csv')
business = pd.read_csv('/Users/linda/SFpal/data/raw_data/Registered_Business.csv')
# Out:
# /Users/linda/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
restaurants[restaurants.business_city=='San Francisco'].shape
# Out:
# (53729, 17)

# %%
restaurants.head()
# Out:
#    business_id     business_name business_address  business_city  \
# 0           10  Tiramisu Kitchen    033 Belden Pl  San Francisco
# 1           10  Tiramisu Kitchen    033 Belden Pl  San Francisco
# 2           10  Tiramisu Kitchen    033 Belden Pl  San Francisco
# 3           10  Tiramisu Kitchen    033 Belden Pl  San Francisco
# 4           10  Tiramisu Kitchen    033 Belden Pl  San Francisco
#
#   business_state business_postal_code  business_latitude  business_longitude  \
# 0             CA                94104          37.791116         -122.403816
# 1             CA                94104          37.791116         -122.403816
# 2             CA                94104          37.791116         -122.403816
# 3             CA                94104          37.791116         -122.403816
# 4             CA                94104          37.791116         -122.403816
#
#           business_location  business_phone_number inspection_id  \
# ...

# %%
business.shape
# Out:
# (210192, 26)

# %%
business.head(2)
# Out:
#       Location Id  Business Account Number Ownership Name  \
# 0  1121427-09-161                  1058430   Edwin Ferran
# 1  1083196-07-161                   346084  Sanchez Julio
#
#                        DBA Name    Street Address           City State  \
# 0                  Edwin Ferran  315 San Juan Ave     El+granada    CA
# 1  Julios Janitorial & Handyman  1439 Shafter Ave  San Francisco    CA
#
#    Source Zipcode Business Start Date Business End Date        ...         \
# 0         94018.0          08/01/2016               NaN        ...
# 1         94124.0          05/24/2001               NaN        ...
#
#   NAICS Code          NAICS Code Description Parking Tax  \
# 0  4800-4999  Transportation and Warehousing       False
# 1        NaN                             NaN       False
#
#   Transient Occupancy Tax LIC Code LIC Code Description Supervisor District  \
# 0                   False      NaN                  NaN                 NaN
# ...

# %%
business['NAICS Code Description'].unique()
# Out:
# array(['Transportation and Warehousing', nan, 'Insurance',
#        'Real Estate and Rental and Leasing Services', 'Retail Trade',
#        'Information', 'Professional, Scientific, and Technical Services',
#        'Construction', 'Manufacturing', 'Multiple', 'Wholesale Trade',
#        'Accommodations', 'Private Education and Health Services',
#        'Food Services', 'Administrative and Support Services',
#        'Arts, Entertainment, and Recreation', 'Certain Services',
#        'Financial Services', 'Utilities'], dtype=object)

# %%
business[business['NAICS Code Description']=='Food Services'].shape
# Out:
# (7646, 26)

# %%
business[business['NAICS Code Description']=='Food Services'].iloc[0:2,0:20]
# Out:
#        Location Id  Business Account Number       Ownership Name  \
# 47  1048748-01-161                  1002255        Koide Jesse L
# 57  0009619-01-001                     9619  Geraldi Nino L Etal
#
#                 DBA Name  Street Address           City State  Source Zipcode  \
# 47         Pink Zebra Sf  636 Stanyan St  San Francisco    CA         94117.0
# 57  Fishermans Grotto #9  2847 Taylor St  San Francisco    CA         94133.0
#
#    Business Start Date Business End Date Location Start Date  \
# 47          08/01/2014               NaN          07/01/2015
# 57          10/01/1968        09/25/2016          10/01/1968
#
#    Location End Date           Mail Address      Mail City Mail Zipcode  \
# 47               NaN         636 Stanyan St  San Francisco        94117
# 57        12/31/2013  4831 Indian Valley Rd         Novato        94947
#
#    Mail State NAICS Code NAICS Code Description Parking Tax  \
# 47         CA  7220-7229          Food Services       False
# ...

# %%
business[business['NAICS Code Description']=='Wholesale Trade'].iloc[0:2,0:20]
# Out:
#        Location Id  Business Account Number        Ownership Name  \
# 29  1082668-07-161                   458060  Fitness Anywhere Llc
# 68  1082685-07-161                   340220    Peterson Catherine
#
#                DBA Name    Street Address           City State  \
# 29         Trx Training  1660 Pacific Ave  San Francisco    CA
# 68  Peterson Represents       103 Wool St  San Francisco    CA
#
#     Source Zipcode Business Start Date Business End Date Location Start Date  \
# 29         94109.0          03/16/2011               NaN          10/15/2015
# 68         94110.0          01/01/1994               NaN          07/12/2016
#
#    Location End Date      Mail Address      Mail City Mail Zipcode Mail State  \
# 29               NaN  1660 Pacific Ave  San Francisco        94109         CA
# 68               NaN       103 Wool St  San Francisco        94110         CA
#
#    NAICS Code NAICS Code Description Parking Tax Transient Occupancy Tax
# ...

# %%
business[business['NAICS Code Description']=='Retail Trade'].iloc[0:2,0:20]
# Out:
#        Location Id  Business Account Number            Ownership Name  \
# 5   0001181-24-001                     1181  Anderson Enterprises Inc
# 15  0003530-05-001                     3530                 Books Inc
#
#             DBA Name      Street Address           City State  Source Zipcode  \
# 5   Vw San Francisco  280 S Van Ness Ave  San Francisco    CA         94103.0
# 15         Books Inc    2251 Chestnut St  San Francisco    CA         94123.0
#
#    Business Start Date Business End Date Location Start Date  \
# 5           10/01/1968               NaN          04/20/2012
# 15          03/01/1977               NaN          05/15/1998
#
#    Location End Date        Mail Address      Mail City Mail Zipcode  \
# 5                NaN  285 S Van Ness Ave  San Francisco        94103
# 15               NaN     1501 Vermont St  San Francisco        94107
#
#    Mail State NAICS Code NAICS Code Description Parking Tax  \
# ...

# %%
business[business['DBA Name'].str.contains("Supermarket")]
# Out:
#            Location Id  Business Account Number               Ownership Name  \
# 14211   0147914-01-001                   147914       Qaqundah Saliba & Amal
# 15890   0163342-01-001                   163342      Marina Supermarket Inc.
# 15933   0163658-03-001                   163658  Ngo Howard & Vuong Dzung My
# 18098   0183736-02-001                   183736           Wakefern Food Corp
# 24477   0308540-01-001                   308540                    Q & H Llc
# 28636   0324683-01-001                   324683          E L I M Corporation
# 42119   0367584-01-001                   367584          New Lite Market Inc
# 45731   0376952-01-001                   376952                 Hing Yue Inc
# 49034   0384771-01-001                   384771          Abc Supermarket Inc
# 66281   0416489-01-001                   416489          Super Star Mart Llc
# 66699   0417131-01-001                   417131   New United Supermarket Inc
# ...

# %%
business[business['DBA Name'].str.contains("Safeway")]
# Out:
#            Location Id  Business Account Number  \
# 4523    0024669-02-001                    24669
# 4524    0024669-04-001                    24669
# 4525    0024669-05-001                    24669
# 4526    0024669-07-001                    24669
# 4527    0024669-10-001                    24669
# 4528    0024669-11-001                    24669
# 4529    0024669-12-001                    24669
# 4530    0024669-13-001                    24669
# 4532    0024669-14-001                    24669
# 4533    0024669-15-001                    24669
# 4534    0024669-16-001                    24669
# 4535    0024669-19-001                    24669
# 4536    0024669-20-001                    24669
# 4537    0024669-21-001                    24669
# 4538    0024669-22-001                    24669
# 4539    0024669-23-999                    24669
# 11396   0467295-05-001                   467295
# 13414   0137466-01-001                   137466
# ...

# %%
business[business['DBA Name'].str.contains("Target")]
# Out:
#            Location Id  Business Account Number  \
# 18020   0183318-01-999                   183318
# 29867   0329548-03-001                   329548
# 34259   0344601-01-001                   344601
# 36410   0351574-04-001                   351574
# 42199   0367786-01-001                   367786
# 64050   0413464-01-999                   413464
# 72150   0426418-02-001                   426418
# 72151   0426418-03-999                   426418
# 83554   0444574-02-001                   444574
# 83555   0444574-03-001                   444574
# 95177   0459269-01-999                   459269
# 104259  0469070-01-001                   469070
# 112492  0477179-01-001                   477179
# 114639  0479200-01-999                   479200
# 116383  0480794-12-001                   480794
# 121054  0485087-01-001                   485087
# 136267  0955909-02-001                   955909
# 148172  1021281-03-151                   444574
# ...
