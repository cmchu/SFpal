# %%
import pandas as pd
import sys
sys.path.append('/Users/linda/SFpal/data') #Linda: Mac

# %%
restaurant = pd.read_csv('/Users/linda/SFpal/data/Restaurants.csv')

# %%
restaurant.head(10)
# Out:
#       Location Id  Business Account Number                Ownership Name  \
# 0  0477020-04-001                   477020           The Cavalier Sf Llc
# 1  0473469-02-001                   473469            Aviles Christina M
# 2  0154077-04-001                   154077  St Francis Memorial Hospital
# 3  0190628-05-001                   190628                    Natali Inc
# 4  0324118-01-001                   324118                 Cajun Pacific
# 5  0488275-03-001                   488275           Sf Treat Lessee Inc
# 6  0345419-01-001                   345419                  Gentilia Inc
# 7  0364643-35-001                   364643            Sodexo America Llc
# 8  0424341-02-001                   424341                 2e Shqair Inc
# 9  0458980-04-001                   458980   Musleh Michael Abu-Ali Isam
#
#                       DBA Name      Street Address  Source Zipcode  \
# 0       The Cavalier Lobby Bar           55 5th St           94103
# ...

# %%
restaurant.shape
# Out:
# (5000, 12)

# %%
restaurant['Location'] = restaurant['Business Location'].apply(lambda x: x.split("\n")[-1])

# %%
restaurant.Location
# Out:
# 0       (37.783206, -122.407093)
# 1       (37.761607, -122.500628)
# 2       (37.789561, -122.417112)
# 3        (37.760859, -122.43552)
# 4       (37.762266, -122.506896)
# 5        (37.79339, -122.392993)
# 6
# 7        (37.789226, -122.39513)
# 8       (37.786168, -122.417605)
# 9       (37.768489, -122.450508)
# 10      (37.794781, -122.400288)
# 11      (37.807882, -122.418442)
# 12       (37.809302, -122.41656)
# 13
# 14
# 15
# 16      (37.795296, -122.406508)
# 17      (37.797703, -122.430746)
# 18       (37.80801, -122.417427)
# 19       (37.78294, -122.410719)
# 20      (37.741035, -122.388603)
# 21       (37.78678, -122.450274)
# 22      (37.794046, -122.398926)
# 23      (37.788943, -122.410904)
# 24      (37.787627, -122.413583)
# 25      (37.788943, -122.410904)
# 26      (37.763524, -122.478362)
# 27      (37.768055, -122.413378)
# 28      (37.768055, -122.413378)
# 29      (37.798538, -122.407714)
#                   ...
# 4970    (37.785287, -122.417007)
# ...
